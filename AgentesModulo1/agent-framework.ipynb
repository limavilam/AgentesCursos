# %%
# 📦 Import Required Libraries
# Standard library imports for system operations and random number generation


# Third-party library for loading environment variables from .env file
from dotenv import load_dotenv

# %%
import os
from random import randint

# %%
from agent_framework import Agent, tool
from agent_framework.openai import OpenAIChatClient

# %%
# 🎲 Tool Function: Random Destination Generator
# This function will be available to the agent as a tool
# The agent can call this function to get random vacation destinations
@tool
def get_random_destination() -> str:
    """Get a random vacation destination.

    Returns:
        str: A randomly selected destination from our predefined list
    """
    # List of popular vacation destinations around the world
    destinations = [
        "Barcelona, Spain",
        "Paris, France",
        "Berlin, Germany",
        "Tokyo, Japan",
        "Sydney, Australia",
        "New York, USA",
        "Cairo, Egypt",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia",
        "Bogota, Colombia",
    ]
    # Return a random destination from the list
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Create OpenAI Chat Client for GitHub Models
# This client connects to GitHub Models API (OpenAI-compatible endpoint)
# Environment variables required:
# - GITHUB_ENDPOINT: API endpoint URL
# - GITHUB_TOKEN: Your GitHub personal access token
# - GITHUB_MODEL_ID: Model to use
openai_chat_client = OpenAIChatClient(
   #base_url=os.environ.get("GITHUB_ENDPOINT"),
    #api_key=os.environ.get("GITHUB_TOKEN"),
    #model_id=os.environ.get("GITHUB_MODEL_ID")
)

# %%
# 🤖 Create the Travel Planning Agent
# This creates a conversational AI agent with specific capabilities:
# - client: The AI model client for generating responses
# - instructions: System prompt that defines the agent's personality and role
# - tools: List of functions the agent can call to perform actions
agent = Agent(
    client=openai_chat_client,
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations.",
    tools=[get_random_destination]  # Our random destination tool function
)

# %%
# 🚀 Run the Agent
# Send a message to the agent and get a response
# The agent will use its tools (get_random_destination) if needed
response = await agent.run("Plan me a day trip")

# %%
# 📋 View Raw Response Object
# This shows the complete response structure including metadata
# Useful for debugging and understanding the response format
response

# %%
# 📖 Extract and Display the Travel Plan
# Get the last message from the conversation (agent's response)s
last_message = response.messages[-1]
# Extract the text content from the message
text_content = last_message.contents[0].text
# Display the formatted travel plan
print("🏖️ Travel plan:")
print(text_content)
# Out:
# 🏖️ Travel plan:
# How about a day trip to Sydney, Australia? Here's a suggested itinerary for your adventure:
#
# ### Morning
# - **Breakfast at The Rocks**: Start your day with a delicious breakfast at one of the charming cafés in The Rocks, an area known for its historic buildings and vibrant atmosphere.
# - **Sydney Opera House**: After breakfast, take a tour of the iconic Sydney Opera House. You can explore its unique architecture and learn about its history.
#
# ### Midday
# - **Lunch by the Harbour**: Head to Circular Quay for lunch at one of the waterfront restaurants. Enjoy stunning views of the Sydney Harbour Bridge while you eat.
# - **Explore the Royal Botanic Garden**: Take a leisurely stroll through the beautiful Royal Botanic Garden, where you can see a variety of native plants and gardens.
#
# ### Afternoon
# - **Visit Bondi Beach**: Make your way to Bondi Beach for some sun and relaxation. You could take a walk along the famous Bondi to Coogee coastal walk for stunning ocean views.
# - **Ice Cream Treat**: Stop for an ice cream at one of the local shops to cool off while enjoying the beach vibe.
#
# ### Evening
# - **Dinner at Darling Harbour**: Head back towards the city and enjoy a delightful dinner at Darling Harbour. There are many restaurants offering a range of cuisines.
# - **Sydney Harbour Cruise**: If time allows, consider taking a sunset cruise of Sydney Harbour for breathtaking views of the skyline as the sun sets.
#
# This itinerary provides a wonderful mix of culture, nature, and relaxation, ensuring you make the most of your day in Sydney! Would you like more details or adjustments to the plan?
